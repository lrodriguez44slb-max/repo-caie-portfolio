# %% [markdown]
# <a href="https://colab.research.google.com/github/lrodriguez44slb-max/repo-caie-portfolio/blob/Python-Project-03/Python_Project_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def word_count(sentence):

    """How many words are in the sentence."""

    return len(sentence.split())



def longest_word(sentence):

    """The longest word in the sentence."""

    longest = ""

    for w in sentence.split():

        if len(w) > len(longest):

            longest = w

    return longest



def count_vowels(text):

    """How many vowels (a e i o u) are in the text."""

    vowels = "aeiou"

    total = 0

    for letter in text.lower():

        if letter in vowels:

            total += 1

    return total



def long_words(sentence, min_len=4):

    """Every word longer than min_len, in CAPITALS."""

    return [w.upper() for w in sentence.split() if len(w) > min_len]



def initials(full_name):

    """Turn 'aisha noor khan' into 'A.N.K.'"""

    return ".".join([part[0].upper() for part in full_name.split()]) + "."



s = "the quick brown fox jumps"

print(word_count(s), longest_word(s), count_vowels(s))

print(long_words(s))

print(initials("aisha noor khan"))
# Out:
# 5 quick 6
# ['QUICK', 'BROWN', 'JUMPS']
# A.N.K.
