# %% [markdown]
# <a href="https://colab.research.google.com/github/lrodriguez44slb-max/repo-caie-portfolio/blob/Phyton-Project-04/Python_Project_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
sales = [500, 1200, 800]

for sale in sales:
    if sale > 1000:
        print(sale)
# Out:
# 1200
