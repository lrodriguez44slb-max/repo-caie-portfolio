# %% [markdown]
# <a href="https://colab.research.google.com/github/lrodriguez44slb-max/repo-caie-portfolio/blob/Python-Project-02/Python_Project_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
marks = 100

if marks >= 80:

    print("A")

elif marks >= 60 and marks < 80:

    print("B")

elif marks >= 40 and marks < 60:

    print("C")

else:

    print("Fail")
# Out:
# A
